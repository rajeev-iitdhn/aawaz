# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import librosa
x, sr = librosa.load("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/Jaane-Nahin-Denge.mp3")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-3e5d88060417> in <module>()
#       1 import librosa
# ----> 2 x, sr = librosa.load("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/Jaane-Nahin-Denge.mp3")
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     117
#     118     y = []
# --> 119     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     120         sr_native = input_file.samplerate
#     121         n_channels = input_file.channels
#
# /usr/local/lib/python3.6/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# ...

# %%
x[2000:12000]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.01508429, 0.03589003,
#        0.03037619], dtype=float32)

# %%
print(x.shape)
print(sr)
# Out:
# (4683420,)
# 22050

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
import IPython.display as ipd
ipd.Audio("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/Jaane-Nahin-Denge.mp3")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy
sr = 22050 # sample rate
T = 2.0    # seconds
t = numpy.linspace(0, T, int(T*sr), endpoint=False) # time variable
x = 0.5*numpy.sin(2*numpy.pi*440*t)

# %% [markdown]
# **Creating a wav file.**

# %%
librosa.output.write_wav("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/xyz.wav", x, sr)

# %%
pip install pydub

# %%
from pydub import AudioSegment

# %%
AudioSegment.from_wav("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/xyz.wav").export("/content/drive/My Drive/ML_works/Recommendation_system/Audio_recommendation/Data_files/yz.mp3", format="mp3")
# Out:
# Exception ignored in: <bound method Wave_write.__del__ of <wave.Wave_write object at 0x7f297a843d68>>
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/wave.py", line 316, in __del__
#     self.close()
#   File "/usr/lib/python3.6/wave.py", line 434, in close
#     self._ensure_header_written(0)
#   File "/usr/lib/python3.6/wave.py", line 454, in _ensure_header_written
#     raise Error('sample width not specified')
# wave.Error: sample width not specified
# Exception ignored in: <bound method Wave_write.__del__ of <wave.Wave_write object at 0x7f297a874400>>
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/wave.py", line 316, in __del__
#     self.close()
#   File "/usr/lib/python3.6/wave.py", line 434, in close
#     self._ensure_header_written(0)
#   File "/usr/lib/python3.6/wave.py", line 454, in _ensure_header_written
#     raise Error('sample width not specified')
# wave.Error: sample width not specified
# ...
